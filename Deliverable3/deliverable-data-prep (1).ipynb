# %%
import pandas as pd
import numpy as np
from random import sample
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
#from pandas import DataFrame as df
from sklearn.linear_model import LinearRegression

# %%
bucket='covid-death'

file_key = 'covid-19-world-cases-deaths-testing.csv'

s3uri = 's3://{}/{}'.format(bucket, file_key)

df = pd.read_csv(s3uri)

# %% [markdown]
# # # Description of index, entries, columns, data types, memory info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132644 entries, 0 to 132643
# Data columns (total 65 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   iso_code                                 132644 non-null  object
#  1   continent                                124170 non-null  object
#  2   location                                 132644 non-null  object
#  3   date                                     132644 non-null  object
#  4   total_cases                              125410 non-null  float64
#  5   new_cases                                125408 non-null  float64
#  6   new_cases_smoothed                       124365 non-null  float64
#  7   total_deaths                             114293 non-null  float64
#  8   new_deaths                               114489 non-null  float64
#  9   new_deaths_smoothed                      124365 non-null  float64
#  10  total_cases_per_million                  124766 non-null  float64
#  11  new_cases_per_million                    124764 non-null  float64
#  12  new_cases_smoothed_per_million           123726 non-null  float64
#  13  total_deaths_per_million                 113662 non-null  float64
#  14  new_deaths_per_million                   113858 non-null  float64
#  15  new_deaths_smoothed_per_million          123726 non-null  float64
#  16  reproduction_rate                        104426 non-null  float64
#  17  icu_patients                             15955 non-null   float64
#  18  icu_patients_per_million                 15955 non-null   float64
#  19  hosp_patients                            18699 non-null   float64
#  20  hosp_patients_per_million                18699 non-null   float64
#  21  weekly_icu_admissions                    1340 non-null    float64
#  22  weekly_icu_admissions_per_million        1340 non-null    float64
#  23  weekly_hosp_admissions                   2127 non-null    float64
#  24  weekly_hosp_admissions_per_million       2127 non-null    float64
#  25  new_tests                                55090 non-null   float64
#  26  total_tests                              55345 non-null   float64
#  27  total_tests_per_thousand                 55345 non-null   float64
#  28  new_tests_per_thousand                   55090 non-null   float64
#  29  new_tests_smoothed                       66893 non-null   float64
#  30  new_tests_smoothed_per_thousand          66893 non-null   float64
#  31  positive_rate                            62869 non-null   float64
#  32  tests_per_case                           62209 non-null   float64
#  33  tests_units                              68912 non-null   object
#  34  total_vaccinations                       33391 non-null   float64
#  35  people_vaccinated                        31843 non-null   float64
#  36  people_fully_vaccinated                  28854 non-null   float64
#  37  total_boosters                           5855 non-null    float64
#  38  new_vaccinations                         27787 non-null   float64
#  39  new_vaccinations_smoothed                59510 non-null   float64
#  40  total_vaccinations_per_hundred           33391 non-null   float64
#  41  people_vaccinated_per_hundred            31843 non-null   float64
#  42  people_fully_vaccinated_per_hundred      28854 non-null   float64
#  43  total_boosters_per_hundred               5855 non-null    float64
#  44  new_vaccinations_smoothed_per_million    59510 non-null   float64
#  45  stringency_index                         108117 non-null  float64
#  46  population                               131704 non-null  float64
#  47  population_density                       120074 non-null  float64
#  48  median_age                               114425 non-null  float64
#  49  aged_65_older                            113159 non-null  float64
#  50  aged_70_older                            113800 non-null  float64
#  51  gdp_per_capita                           115174 non-null  float64
#  52  extreme_poverty                          77021 non-null   float64
#  53  cardiovasc_death_rate                    114669 non-null  float64
#  54  diabetes_prevalence                      118421 non-null  float64
#  55  female_smokers                           89329 non-null   float64
#  56  male_smokers                             88037 non-null   float64
#  57  handwashing_facilities                   57713 non-null   float64
#  58  hospital_beds_per_thousand               104208 non-null  float64
#  59  life_expectancy                          123313 non-null  float64
#  60  human_development_index                  114771 non-null  float64
#  61  excess_mortality_cumulative_absolute     4656 non-null    float64
#  62  excess_mortality_cumulative              4656 non-null    float64
#  63  excess_mortality                         4656 non-null    float64
#  64  excess_mortality_cumulative_per_million  4656 non-null    float64
# dtypes: float64(60), object(5)
# memory usage: 65.8+ MB

# %%
df.shape
# Out:
# (132644, 65)

# %%
# number of unique values of a column
df["location"].nunique()
# show unique values of a column
df["date"].unique()
# number of unique values alltogether
df.columns.nunique()
# value counts
df['total_cases'].value_counts()
# Out:
# 1.0           1243
# 4.0            758
# 3.0            620
# 2.0            612
# 721.0          596
#               ...
# 341879.0         1
# 135441.0         1
# 3783597.0        1
# 85469.0          1
# 10377818.0       1
# Name: total_cases, Length: 73232, dtype: int64

# %%
df.sample()
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 51353  OWID_HIC       NaN  High income  2020-07-30    7528619.0    88269.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 51353           83049.429      354417.0      1541.0             1317.857  ...
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 51353             NaN           NaN                     NaN
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 51353                         NaN              NaN                      NaN
#
#        excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 51353                                   NaN                          NaN
#
#        excess_mortality  excess_mortality_cumulative_per_million
# 51353               NaN                                      NaN
#
# [1 rows x 65 columns]

# %% [markdown]
# ## Basic functions to inspect the data

# %%
df.isnull().sum()
# Out:
# iso_code                                        0
# continent                                    8474
# location                                        0
# date                                            0
# total_cases                                  7234
#                                             ...
# human_development_index                     17873
# excess_mortality_cumulative_absolute       127988
# excess_mortality_cumulative                127988
# excess_mortality                           127988
# excess_mortality_cumulative_per_million    127988
# Length: 65, dtype: int64

# %%
df["total_cases"] = df["total_cases"].fillna(df["total_cases"].mean())
df["total_tests"] = df["total_tests"].fillna(df["total_tests"].mean())
df["new_deaths"] = df["new_deaths"].fillna(df["new_deaths"].mean())
df["positive_rate"] = df["positive_rate"].fillna(df["positive_rate"].mean())
df["people_vaccinated"] = df["people_vaccinated"].fillna(df["people_vaccinated"].mean())
df["people_fully_vaccinated"] = df["people_fully_vaccinated"].fillna(df["people_fully_vaccinated"].mean())
df["population_density"] = df["population_density"].fillna(df["population_density"].mean())
df["total_vaccinations"] = df["total_vaccinations"].fillna(df["total_vaccinations"].mean())

# %%
df.isnull().sum()
# Out:
# iso_code                                        0
# continent                                    8474
# location                                        0
# date                                            0
# total_cases                                     0
#                                             ...
# human_development_index                     17873
# excess_mortality_cumulative_absolute       127988
# excess_mortality_cumulative                127988
# excess_mortality                           127988
# excess_mortality_cumulative_per_million    127988
# Length: 65, dtype: int64

# %%
##training
df['new_deaths'].isnull().sum()
df
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 132639      ZWE    Africa     Zimbabwe  2021-11-07     133187.0       19.0
# 132640      ZWE    Africa     Zimbabwe  2021-11-08     133205.0       18.0
# 132641      ZWE    Africa     Zimbabwe  2021-11-09     133242.0       37.0
# 132642      ZWE    Africa     Zimbabwe  2021-11-10     133302.0       60.0
# 132643      ZWE    Africa     Zimbabwe  2021-11-11     133329.0       27.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                      NaN           NaN  184.004114                  NaN
# 1                      NaN           NaN  184.004114                  NaN
# 2                      NaN           NaN  184.004114                  NaN
# 3                      NaN           NaN  184.004114                  NaN
# 4                      NaN           NaN  184.004114                  NaN
# ...                    ...           ...         ...                  ...
# 132639              30.000        4685.0    0.000000                1.000
# 132640              28.286        4690.0    5.000000                1.571
# 132641              27.857        4691.0    1.000000                1.143
# 132642              30.143        4694.0    3.000000                1.429
# 132643              31.000        4694.0    0.000000                1.286
#
#         ...  female_smokers  male_smokers  handwashing_facilities  \
# 0       ...             NaN           NaN                  37.746
# 1       ...             NaN           NaN                  37.746
# 2       ...             NaN           NaN                  37.746
# 3       ...             NaN           NaN                  37.746
# 4       ...             NaN           NaN                  37.746
# ...     ...             ...           ...                     ...
# 132639  ...             1.6          30.7                  36.791
# 132640  ...             1.6          30.7                  36.791
# 132641  ...             1.6          30.7                  36.791
# 132642  ...             1.6          30.7                  36.791
# 132643  ...             1.6          30.7                  36.791
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                              0.5            64.83                    0.511
# 1                              0.5            64.83                    0.511
# 2                              0.5            64.83                    0.511
# 3                              0.5            64.83                    0.511
# 4                              0.5            64.83                    0.511
# ...                            ...              ...                      ...
# 132639                         1.7            61.49                    0.571
# 132640                         1.7            61.49                    0.571
# 132641                         1.7            61.49                    0.571
# 132642                         1.7            61.49                    0.571
# 132643                         1.7            61.49                    0.571
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ...                                      ...                          ...
# 132639                                   NaN                          NaN
# 132640                                   NaN                          NaN
# 132641                                   NaN                          NaN
# 132642                                   NaN                          NaN
# 132643                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 0                    NaN                                      NaN
# 1                    NaN                                      NaN
# 2                    NaN                                      NaN
# 3                    NaN                                      NaN
# 4                    NaN                                      NaN
# ...                  ...                                      ...
# 132639               NaN                                      NaN
# 132640               NaN                                      NaN
# 132641               NaN                                      NaN
# 132642               NaN                                      NaN
# 132643               NaN                                      NaN
#
# [132644 rows x 65 columns]

# %%
x = df[['total_cases','total_tests','positive_rate','people_vaccinated','people_fully_vaccinated','population_density','total_vaccinations']]
y = df['new_deaths']
x.head()
# Out:
#    total_cases   total_tests  positive_rate  people_vaccinated  \
# 0          5.0  1.190922e+07       0.086493       5.854553e+07
# 1          5.0  1.190922e+07       0.086493       5.854553e+07
# 2          5.0  1.190922e+07       0.086493       5.854553e+07
# 3          5.0  1.190922e+07       0.086493       5.854553e+07
# 4          5.0  1.190922e+07       0.086493       5.854553e+07
#
#    people_fully_vaccinated  population_density  total_vaccinations
# 0             4.009685e+07              54.422        1.074031e+08
# 1             4.009685e+07              54.422        1.074031e+08
# 2             4.009685e+07              54.422        1.074031e+08
# 3             4.009685e+07              54.422        1.074031e+08
# 4             4.009685e+07              54.422        1.074031e+08

# %%
# Split into test and training sets
test_size = 0.33
seed = 7
x_train, x_test, y_train, y_test =  train_test_split(x, y, test_size=test_size, random_state=seed)

# %%
x_train
# Out:
#          total_cases   total_tests  positive_rate  people_vaccinated  \
# 84631   7.740090e+05  5.179331e+06       0.132000       5.854553e+07
# 126349  5.361017e+07  1.190922e+07       0.086493       8.123186e+08
# 12044   1.489810e+05  3.663909e+06       0.110000       5.854553e+07
# 54584   6.549373e+06  7.785040e+07       0.073000       5.854553e+07
# 106889  2.038988e+06  1.190922e+07       0.086493       5.854553e+07
# ...              ...           ...            ...                ...
# 66455   2.859000e+03  1.190922e+07       0.086493       5.854553e+07
# 53459   4.461780e+05  3.299071e+06       0.184000       8.629530e+05
# 10742   1.790000e+02  1.190922e+07       0.086493       5.854553e+07
# 49689   3.156000e+03  1.190922e+07       0.086493       5.854553e+07
# 61615   6.329070e+05  6.071373e+06       0.148000       5.854553e+07
#
#         people_fully_vaccinated  population_density  total_vaccinations
# 84631              4.009685e+07          508.544000        1.074031e+08
# 126349             9.841983e+07          399.292664        1.189528e+09
# 12044              4.009685e+07          375.564000        1.074031e+08
# 54584              4.009685e+07          450.419000        1.074031e+08
# 106889             4.009685e+07         1209.088000        1.074031e+08
# ...                         ...                 ...                 ...
# 66455              4.009685e+07          594.561000        1.074031e+08
# 53459              2.797270e+05          108.043000        1.142680e+06
# 10742              4.009685e+07          664.463000        1.074031e+08
# 49689              4.009685e+07           66.191000        1.074031e+08
# 61615              4.009685e+07          109.285000        1.074031e+08
#
# [88871 rows x 7 columns]

# %%
x_test
# Out:
#          total_cases   total_tests  positive_rate  people_vaccinated  \
# 114107  2.316900e+04  1.190922e+07       0.086493       1.675600e+05
# 13220   2.242000e+03  1.190922e+07       0.086493       5.854553e+07
# 61815   8.460330e+05  1.061067e+07       0.044000       3.856293e+06
# 14107   1.130000e+02  5.707400e+04       0.003000       5.854553e+07
# 81452   4.790710e+05  5.059147e+06       0.046000       5.854553e+07
# ...              ...           ...            ...                ...
# 122046  2.038988e+06  1.190922e+07       0.086493       5.854553e+07
# 88174   3.648289e+07  1.190922e+07       0.086493       1.584546e+08
# 97484   2.144630e+05  1.985181e+06       0.086493       1.261828e+06
# 74917   8.160000e+03  1.190922e+07       0.086493       5.854553e+07
# 33482   1.956000e+03  6.358000e+03       0.319000       5.854553e+07
#
#         people_fully_vaccinated  population_density  total_vaccinations
# 114107             4.066700e+04            3.612000        2.082270e+05
# 13220              4.009685e+07           99.110000        1.074031e+08
# 61815              3.450344e+06          109.285000        7.306637e+06
# 14107              4.009685e+07           21.188000        1.074031e+08
# 81452              4.009685e+07           80.080000        1.904169e+06
# ...                         ...                 ...                 ...
# 122046             4.009685e+07           12.253000        1.074031e+08
# 88174              9.441081e+07          399.292664        2.472828e+08
# 97484              9.289790e+05          227.322000        2.190807e+06
# 74917              4.009685e+07           15.196000        1.074031e+08
# 33482              4.009685e+07          222.873000        1.074031e+08
#
# [43773 rows x 7 columns]

# %%
y_train
# Out:
# 84631       28.000000
# 126349    3226.000000
# 12044       25.000000
# 54584      940.000000
# 106889     184.004114
#              ...
# 66455        0.000000
# 53459      152.000000
# 10742        0.000000
# 49689        0.000000
# 61615       71.000000
# Name: new_deaths, Length: 88871, dtype: float64

# %%
y_test
# Out:
# 114107       5.000000
# 13220        0.000000
# 61815        0.000000
# 14107      184.004114
# 81452       13.000000
#              ...
# 122046     184.004114
# 88174     1462.000000
# 97484        1.000000
# 74917        2.000000
# 33482       12.000000
# Name: new_deaths, Length: 43773, dtype: float64

# %%
# Create Regression Model
# Use Linear Regression Model to train our data
model = LinearRegression()

# %%
# Train the model
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Use model to make predictions
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([186.03112879,  19.5717323 , 226.91491412, ..., 216.99784001,
#         20.23856942, 130.80732136])

# %%
model.score(x_test, y_test)
# Out:
# 0.6667080997357822

# %%
# Result
# create new data frame
new_df = x_test.copy()

# %%
new_df['Actual_New_Death'] = y_test
new_df['Predicted_New_Death'] = y_pred
new_df
# Out:
#          total_cases   total_tests  positive_rate  people_vaccinated  \
# 114107  2.316900e+04  1.190922e+07       0.086493       1.675600e+05
# 13220   2.242000e+03  1.190922e+07       0.086493       5.854553e+07
# 61815   8.460330e+05  1.061067e+07       0.044000       3.856293e+06
# 14107   1.130000e+02  5.707400e+04       0.003000       5.854553e+07
# 81452   4.790710e+05  5.059147e+06       0.046000       5.854553e+07
# ...              ...           ...            ...                ...
# 122046  2.038988e+06  1.190922e+07       0.086493       5.854553e+07
# 88174   3.648289e+07  1.190922e+07       0.086493       1.584546e+08
# 97484   2.144630e+05  1.985181e+06       0.086493       1.261828e+06
# 74917   8.160000e+03  1.190922e+07       0.086493       5.854553e+07
# 33482   1.956000e+03  6.358000e+03       0.319000       5.854553e+07
#
#         people_fully_vaccinated  population_density  total_vaccinations  \
# 114107             4.066700e+04            3.612000        2.082270e+05
# 13220              4.009685e+07           99.110000        1.074031e+08
# 61815              3.450344e+06          109.285000        7.306637e+06
# 14107              4.009685e+07           21.188000        1.074031e+08
# 81452              4.009685e+07           80.080000        1.904169e+06
# ...                         ...                 ...                 ...
# 122046             4.009685e+07           12.253000        1.074031e+08
# 88174              9.441081e+07          399.292664        2.472828e+08
# 97484              9.289790e+05          227.322000        2.190807e+06
# 74917              4.009685e+07           15.196000        1.074031e+08
# 33482              4.009685e+07          222.873000        1.074031e+08
#
#         Actual_New_Death  Predicted_New_Death
# 114107          5.000000           186.031129
# 13220           0.000000            19.571732
# 61815           0.000000           226.914914
# 14107         184.004114            10.859422
# 81452          13.000000            25.361097
# ...                  ...                  ...
# 122046        184.004114           185.469066
# 88174        1462.000000          2723.212626
# 97484           1.000000           216.997840
# 74917           2.000000            20.238569
# 33482          12.000000           130.807321
#
# [43773 rows x 9 columns]
